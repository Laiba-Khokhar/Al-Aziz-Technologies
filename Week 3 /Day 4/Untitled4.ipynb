# %%
import pandas as pd

data = {
    "Order_Date": [
        "2025-01-05", "2025-01-12", "2025-01-18", "2025-02-03",
        "2025-02-15", "2025-02-22", "2025-03-04", "2025-03-12",
        "2025-03-20", "2025-04-02", "2025-04-15", "2025-04-25",
        "2025-05-05", "2025-05-18", "2025-06-03", "2025-06-15",
        "2025-06-28", "2025-07-10", "2025-07-22", "2025-08-05"
    ],
    "Product": [
        "Laptop", "Mouse", "Keyboard", "Monitor", "Laptop",
        "Printer", "Mouse", "Keyboard", "Monitor", "Laptop",
        "Printer", "Mouse", "Laptop", "Keyboard", "Monitor",
        "Printer", "Mouse", "Laptop", "Keyboard", "Monitor"
    ],
    "Category": [
        "Electronics", "Accessories", "Accessories", "Electronics",
        "Electronics", "Office", "Accessories", "Accessories",
        "Electronics", "Electronics", "Office", "Accessories",
        "Electronics", "Accessories", "Electronics", "Office",
        "Accessories", "Electronics", "Accessories", "Electronics"
    ],
    "Region": [
        "Lahore", "Karachi", "Islamabad", "Lahore", "Karachi",
        "Islamabad", "Lahore", "Karachi", "Islamabad", "Lahore",
        "Karachi", "Islamabad", "Lahore", "Karachi", "Islamabad",
        "Lahore", "Karachi", "Islamabad", "Lahore", "Karachi"
    ],
    "Quantity": [
        2, 10, 5, 3, 1, 4, 12, 6, 2, 3,
        5, 15, 2, 8, 3, 6, 20, 1, 7, 4
    ],
    "Unit_Price": [
        85000, 1500, 3000, 25000, 85000, 18000, 1500, 3000, 25000, 85000,
        18000, 1500, 85000, 3000, 25000, 18000, 1500, 85000, 3000, 25000
    ]
}

df = pd.DataFrame(data)

df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["Sales"] = df["Quantity"] * df["Unit_Price"]

df
# Out:
#    Order_Date   Product     Category     Region  Quantity  Unit_Price   Sales
# 0  2025-01-05    Laptop  Electronics     Lahore         2       85000  170000
# 1  2025-01-12     Mouse  Accessories    Karachi        10        1500   15000
# 2  2025-01-18  Keyboard  Accessories  Islamabad         5        3000   15000
# 3  2025-02-03   Monitor  Electronics     Lahore         3       25000   75000
# 4  2025-02-15    Laptop  Electronics    Karachi         1       85000   85000
# 5  2025-02-22   Printer       Office  Islamabad         4       18000   72000
# 6  2025-03-04     Mouse  Accessories     Lahore        12        1500   18000
# 7  2025-03-12  Keyboard  Accessories    Karachi         6        3000   18000
# 8  2025-03-20   Monitor  Electronics  Islamabad         2       25000   50000
# 9  2025-04-02    Laptop  Electronics     Lahore         3       85000  255000
# 10 2025-04-15   Printer       Office    Karachi         5       18000   90000
# ...

# %%
print(" FIRST 5 ROWS")
display(df.head())

print("\n DATASET SHAPE ")
print(df.shape)

print("\n COLUMN NAMES ")
print(df.columns.tolist())

print("\n DATA TYPES ")
print(df.dtypes)

print("\n MISSING VALUES ")
print(df.isnull().sum())
# Out:
#  FIRST 5 ROWS
#   Order_Date   Product     Category     Region  Quantity  Unit_Price   Sales
# 0 2025-01-05    Laptop  Electronics     Lahore         2       85000  170000
# 1 2025-01-12     Mouse  Accessories    Karachi        10        1500   15000
# 2 2025-01-18  Keyboard  Accessories  Islamabad         5        3000   15000
# 3 2025-02-03   Monitor  Electronics     Lahore         3       25000   75000
# 4 2025-02-15    Laptop  Electronics    Karachi         1       85000   85000
#  DATASET SHAPE
# (20, 7)
#
#  COLUMN NAMES
# ['Order_Date', 'Product', 'Category', 'Region', 'Quantity', 'Unit_Price', 'Sales']
#
#  DATA TYPES
# Order_Date    datetime64[ns]
# Product               object
# Category              object
# Region                object
# Quantity               int64
# Unit_Price             int64
# Sales                  int64
# dtype: object
#
#  MISSING VALUES
# Order_Date    0
# Product       0
# Category      0
# Region        0
# Quantity      0
# Unit_Price    0
# ...

# %%
df["Sales"].describe()
# Out:
# count        20.000000
# mean      74925.000000
# std       63750.804948
# min       15000.000000
# 25%       22125.000000
# 50%       73500.000000
# 75%       92500.000000
# max      255000.000000
# Name: Sales, dtype: float64

# %%
print("Mean:", df["Sales"].mean())
print("Median:", df["Sales"].median())
print("Mode:", df["Sales"].mode()[0])
# Out:
# Mean: 74925.0
# Median: 73500.0
# Mode: 15000

# %%
print("Variance:", df["Sales"].var())
print("Standard Deviation:", df["Sales"].std())
# Out:
# Variance: 4064165131.5789475
# Standard Deviation: 63750.80494847847

# %%
Q1 = df["Sales"].quantile(0.25)
Q2 = df["Sales"].quantile(0.50)
Q3 = df["Sales"].quantile(0.75)

print("Q1 (25%):", Q1)
print("Q2 (50% - Median):", Q2)
print("Q3 (75%):", Q3)
# Out:
# Q1 (25%): 22125.0
# Q2 (50% - Median): 73500.0
# Q3 (75%): 92500.0

# %%
correlation = df["Quantity"].corr(df["Sales"])

print("Correlation between Quantity and Sales:", correlation)
# Out:
# Correlation between Quantity and Sales: -0.5217291699569825

# %%
Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[(df["Sales"] < lower_limit) | (df["Sales"] > upper_limit)]

print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
print("\nOutliers:")
display(outliers)
# Out:
# Lower Limit: -83437.5
# Upper Limit: 198062.5
#
# Outliers:
#   Order_Date Product     Category  Region  Quantity  Unit_Price   Sales
# 9 2025-04-02  Laptop  Electronics  Lahore         3       85000  255000

# %%
import matplotlib.pyplot as plt

plt.hist(df["Sales"], bins=8)

plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt

product_sales = df.groupby("Product")["Sales"].sum()

plt.bar(product_sales.index, product_sales.values)

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df["Order_Date"], df["Sales"], marker="o")

plt.title("Sales Trend Over Time")
plt.xlabel("Order Date")
plt.ylabel("Sales")

plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Quantity"], df["Sales"])

plt.title("Quantity vs Sales")
plt.xlabel("Quantity")
plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.boxplot(df["Sales"])

plt.title("Sales Box Plot")
plt.ylabel("Sales")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df[["Quantity", "Unit_Price", "Sales"]].corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

category_sales = df.groupby("Category")["Sales"].sum()

plt.bar(category_sales.index, category_sales.values)

plt.title("Sales Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
print(" KEY EDA FINDINGS ")

print("\n1. Top Product by Sales:")
print(df.groupby("Product")["Sales"].sum().idxmax())

print("\n2. Top Category by Sales:")
print(df.groupby("Category")["Sales"].sum().idxmax())

print("\n3. Top Region by Sales:")
print(df.groupby("Region")["Sales"].sum().idxmax())

print("\n4. Highest Single Sale:")
print(df["Sales"].max())

print("\n5. Lowest Single Sale:")
print(df["Sales"].min())

print("\n6. Average Sale:")
print(df["Sales"].mean())

print("\n7. Total Sales:")
print(df["Sales"].sum())
# Out:
#  KEY EDA FINDINGS
#
# 1. Top Product by Sales:
# Laptop
#
# 2. Top Category by Sales:
# Electronics
#
# 3. Top Region by Sales:
# Lahore
#
# 4. Highest Single Sale:
# 255000
#
# 5. Lowest Single Sale:
# 15000
#
# 6. Average Sale:
# 74925.0
#
# 7. Total Sales:
# 1498500

# %%
print("EDA SUMMARY")

print("Total Sales:", df["Sales"].sum())
print("Average Sale:", df["Sales"].mean())
print("Highest Sale:", df["Sales"].max())
print("Lowest Sale:", df["Sales"].min())

print("\nTop Product:")
print(df.groupby("Product")["Sales"].sum().idxmax())

print("\nTop Category:")
print(df.groupby("Category")["Sales"].sum().idxmax())

print("\nTop Region:")
print(df.groupby("Region")["Sales"].sum().idxmax())

print("\nCorrelation between Quantity and Sales:")
print(df["Quantity"].corr(df["Sales"]))
# Out:
# EDA SUMMARY
# Total Sales: 1498500
# Average Sale: 74925.0
# Highest Sale: 255000
# Lowest Sale: 15000
#
# Top Product:
# Laptop
#
# Top Category:
# Electronics
#
# Top Region:
# Lahore
#
# Correlation between Quantity and Sales:
# -0.5217291699569825
